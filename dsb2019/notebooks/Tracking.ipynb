# %%
import os
os.environ["TRACKING_FILE"]='/home/bfilippov/oss/dsb2019/dsb2019/tracking.csv'
from dsb2019.models.tracking import track_experiment, track_submission_info

# %%
0.998367624965148 - 0.9960614034505578
# Out:
# 0.0023062215145901455

# %%
track_experiment("Assessment features", 0.9960614034505578, [0.9647463955228139,
  0.9979926126086378,
  0.9567602265050382,
  1.0106369948895797,
  1.0501707877267201], "7cde9066aadad7a31931d333cbfcc5f74f157a0c")


track_submission_info("Assessment features", "Regression baseline submission ass", "0.547")
# Out:
#                              name                              time  \
# 0                   Game baseline  2019-11-19 16:51:22.976533+04:00
# 1  Time + calendar features as is  2019-11-04 02:46:40.201648+04:00
# 2             Assessment features  2020-01-22 10:23:04.915758+04:00
# 3             Add grouped eventid  2020-01-18 16:21:22.613843+04:00
# 4                Exponent mov avg  2020-01-18 23:42:21.222268+04:00
#
#    mean_score                                          cv_scores  \
# 0    0.521635  [0.5537180482275439, 0.5369835700820295, 0.523...
# 1    0.509131  [0.53695404946506, 0.5242692903114117, 0.50829...
# 2    0.996061  [0.9647463955228139, 0.9979926126086378, 0.956...
# 3    1.000663  [0.9686826832495222, 1.0083843763046314, 0.960...
# 4    0.997933  [0.9658515696471883, 1.007380563180694, 0.9545...
#
#                               notebook_path  \
# 0             notebooks/Game baseline.ipynb
# 1                       Time features.ipynb
# ...

# %%
track_experiment("Exponent mov avg", 0.9979330906153304,
 [0.9658515696471883,
  1.007380563180694,
  0.9545393063586448,
  1.011410324345738,
  1.050483689544387], "Nothing")
# Out:
#                              name                              time  \
# 0                   Game baseline  2019-11-19 16:51:22.976533+04:00
# 1  Time + calendar features as is  2019-11-04 02:46:40.201648+04:00
# 2             Assessment features  2020-01-22 10:23:04.915758+04:00
# 3             Add grouped eventid  2020-01-18 16:21:22.613843+04:00
# 4                Exponent mov avg  2020-01-22 10:23:05.256834+04:00
#
#    mean_score                                          cv_scores  \
# 0    0.521635  [0.5537180482275439, 0.5369835700820295, 0.523...
# 1    0.509131  [0.53695404946506, 0.5242692903114117, 0.50829...
# 2    0.996061  [0.9647463955228139, 0.9979926126086378, 0.956...
# 3    1.000663  [0.9686826832495222, 1.0083843763046314, 0.960...
# 4    0.997933  [0.9658515696471883, 1.007380563180694, 0.9545...
#
#                               notebook_path  \
# 0             notebooks/Game baseline.ipynb
# 1                       Time features.ipynb
# ...

# %%
track_experiment("Add grouped eventid", 1.0006629835045557,
 [0.9686826832495222,
  1.0083843763046314,
  0.9603410954528153,
  1.0117610416953635,
  1.0541457208204468], "Nothing")
# Out:
#                              name                              time  \
# 0                   Game baseline  2019-11-19 16:51:22.976533+04:00
# 1  Time + calendar features as is  2019-11-04 02:46:40.201648+04:00
# 2             Assessment features  2020-01-22 10:23:04.915758+04:00
# 3             Add grouped eventid  2020-01-22 10:23:05.407748+04:00
# 4                Exponent mov avg  2020-01-22 10:23:05.256834+04:00
#
#    mean_score                                          cv_scores  \
# 0    0.521635  [0.5537180482275439, 0.5369835700820295, 0.523...
# 1    0.509131  [0.53695404946506, 0.5242692903114117, 0.50829...
# 2    0.996061  [0.9647463955228139, 0.9979926126086378, 0.956...
# 3    1.000663  [0.9686826832495222, 1.0083843763046314, 0.960...
# 4    0.997933  [0.9658515696471883, 1.007380563180694, 0.9545...
#
#                               notebook_path  \
# 0             notebooks/Game baseline.ipynb
# 1                       Time features.ipynb
# ...

# %%
track_experiment("NN baseline", 1.1009174605446925, [1.080805501698279, 1.1077282052716182, 1.0682340314009167, 1.1059859871300355, 1.1418335772226125], "Nothing")

track_submission_info("NN baseline", "NN submission", "0.481")
# Out:
#                              name                              time  \
# 0                   Game baseline  2019-11-19 16:51:22.976533+04:00
# 1  Time + calendar features as is  2019-11-04 02:46:40.201648+04:00
# 2             Assessment features  2020-01-22 10:23:04.915758+04:00
# 3             Add grouped eventid  2020-01-22 10:23:05.407748+04:00
# 4                Exponent mov avg  2020-01-22 10:23:05.256834+04:00
# 5                     NN baseline  2020-01-22 10:23:46.263557+04:00
#
#    mean_score                                          cv_scores  \
# 0    0.521635  [0.5537180482275439, 0.5369835700820295, 0.523...
# 1    0.509131  [0.53695404946506, 0.5242692903114117, 0.50829...
# 2    0.996061  [0.9647463955228139, 0.9979926126086378, 0.956...
# 3    1.000663  [0.9686826832495222, 1.0083843763046314, 0.960...
# 4    0.997933  [0.9658515696471883, 1.007380563180694, 0.9545...
# 5    1.100917  [1.080805501698279, 1.1077282052716182, 1.0682...
#
# ...

# %%
track_experiment("LayerNormalization", 1.1175286831465256, [1.0733702287277525, 1.1139393497806076, 1.1190090496131775, 1.1321305450978438, 1.1491942425132466], "Nothing")
# Out:
#                              name                              time  \
# 0                   Game baseline  2019-11-19 16:51:22.976533+04:00
# 1  Time + calendar features as is  2019-11-04 02:46:40.201648+04:00
# 2             Assessment features  2020-01-22 10:23:04.915758+04:00
# 3             Add grouped eventid  2020-01-22 10:23:05.407748+04:00
# 4                Exponent mov avg  2020-01-22 10:23:05.256834+04:00
# 5                     NN baseline  2020-01-22 10:23:46.263557+04:00
# 6              LayerNormalization  2020-01-22 10:31:57.296419+04:00
#
#    mean_score                                          cv_scores  \
# 0    0.521635  [0.5537180482275439, 0.5369835700820295, 0.523...
# 1    0.509131  [0.53695404946506, 0.5242692903114117, 0.50829...
# 2    0.996061  [0.9647463955228139, 0.9979926126086378, 0.956...
# 3    1.000663  [0.9686826832495222, 1.0083843763046314, 0.960...
# 4    0.997933  [0.9658515696471883, 1.007380563180694, 0.9545...
# ...
