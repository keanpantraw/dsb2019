# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext line_profiler

# %%
import os
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, cross_val_score
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from functools import reduce
from sklearn.metrics import cohen_kappa_score
from sklearn.model_selection import cross_val_score
import json
import numba
from functools import partial
from pandas.io.json import json_normalize

from multiprocessing import Pool, cpu_count
from dsb2019.models.tracking import track_experiment, track_submission_info
from dsb2019.data.validation import InstallationFold, cross_validate, quad_kappa
from dsb2019.visualization import session_browser
from dsb2019.data import DATA_DIR
from dsb2019.models import MODELS_DIR
from sklearn.ensemble import RandomForestClassifier
from tqdm import tqdm
import hyperopt
import joblib
from hyperopt import hp, fmin, Trials, tpe, STATUS_OK
tqdm.pandas()
pd.options.display.max_rows=999

# %%
train = pd.read_csv(DATA_DIR / 'raw/train.csv')
test = pd.read_csv(DATA_DIR / 'raw/test.csv')
train_labels = pd.read_csv(DATA_DIR / 'raw/train_labels.csv')
submission = pd.read_csv(DATA_DIR / 'raw/sample_submission.csv')

# %%
games = ['Scrub-A-Dub', 'All Star Sorting', 'Mushroom Sorter (Assessment)',
       'Air Show', 'Crystals Rule', 'Bird Measurer (Assessment)',
       'Dino Drink', 'Bubble Bath', 'Dino Dive', 'Chow Time',
       'Cauldron Filler (Assessment)', 'Pan Balance', 'Happy Camel',
       'Cart Balancer (Assessment)', 'Chest Sorter (Assessment)',
       'Leaf Leader']


def unwrap_event_data(df):
    unwrapped = json_normalize(df.event_data.apply(json.loads))
    return pd.concat([unwrapped.reset_index(),df.reset_index()],axis=1)


def process_installations_parallel(process_installations, process_log, df, *dataframes):
    installations = df.installation_id.unique()
    jobs = []
    n_jobs=cpu_count()
    with joblib.Parallel(n_jobs=n_jobs) as workers:
        chunk_size = len(installations) // n_jobs
        for pos, i in enumerate(range(0, len(installations), chunk_size)):
            inst_chunk = installations[i:min(i + chunk_size, len(installations))]
            df_chunk = df[df.installation_id.isin(inst_chunk)].copy()
            dataframes_chunk = [d[d.installation_id.isin(inst_chunk)].copy() for d in dataframes]
            jobs.append(joblib.delayed(process_installations)(process_log, df_chunk, *dataframes_chunk, position=pos))
        result = []
        for result_df in workers(jobs):
            result.append(result_df.reset_index())
    return pd.concat(result).drop("index", axis=1)


def process_installations(process_log, train_labels, train, position=0):
    result = []
    train["timestamp"] = pd.to_datetime(train.timestamp)
    train = train.drop(["event_count"], axis=1)
    train=train.sort_values("timestamp")
    installations = train.groupby("installation_id")
    for i, game_session, title, installation_id, accuracy_group in tqdm(train_labels[["game_session", "title", "installation_id", "accuracy_group"]].itertuples(), 
                                                              total=len(train_labels), position=position):
        player_log = installations.get_group(installation_id).reset_index()
        log_length = player_log[(player_log.game_session==game_session) & (player_log.title==title)].index[0]
        player_log = player_log.iloc[:(log_length + 1)]
        player_log["accuracy_group"] = accuracy_group
        player_log["target_game_session"] = game_session
        features = process_log(player_log)
        features["installation_id"] = installation_id
        features["accuracy_group"] = accuracy_group
        result.append(features)
    return pd.DataFrame(data=result).fillna(-1)


def calculate_ratios(df):
    if len(df)==0:
        return 0, 0, None

    n_correct=df.correct_move.sum()
    n_incorrect=df.wrong_move.sum()
    ratio=n_correct/(n_correct+n_incorrect)
    return n_correct, n_incorrect, ratio


def make_move_stats(assessment, df, title):
    result = []
    result.extend(zip(["n_correct " + title, "n_incorrect " + title, "global_ratio " + title], calculate_ratios(df)))
    return {k: v for k,v in result}


def shrink_session(group):
    group = populate_correct_moves(group)
    correct_moves = group[group.correct_move]
    correct_timestamps = correct_moves.timestamp
    correct_turns = correct_moves.event_count
    time_between_correct_moves = (correct_timestamps - correct_timestamps.shift(1)).dropna() / np.timedelta64(1, "m")
    turns_between_correct_moves = (correct_turns - correct_turns.shift(1)).dropna()
    result = {
    } 
    result["start_time"] = group.timestamp.min()
    result["end_time"] = group.timestamp.max()
    result["duration"] = result["end_time"] - result["start_time"]
    result["correct_move"] = group.correct_move.sum()
    result["wrong_move"] = group.wrong_move.sum()
    result["title"] = group.title.iloc[0]
    result["installation_id"] = group.installation_id.iloc[0]
    result["game_session"] = group.game_session.iloc[0]
    return result


def populate_correct_moves(history: pd.DataFrame) -> pd.DataFrame:
    if "correct" in history.columns:
        history["correct_move"] = history.correct == True
        history["wrong_move"] = history.correct == False
    else:
        history["correct_move"]=False
        history["wrong_move"]=False
    return history

    
def make_base_time_features(assessment, history):
    start_end_times = history
    duration_minutes = start_end_times.duration / np.timedelta64(1, "m")
    result = {
        "mean_session_time_minutes": round(duration_minutes.mean(), 0), 
    }
    last_event_time = assessment.timestamp
    first_event_time = start_end_times.start_time.min()
    
    days_active = round((last_event_time - first_event_time) / np.timedelta64(1, "D"), 0) + 1
    result["games_per_day"] = round(history.game_session.nunique() / days_active, 2)
    
    minutes_between_games = ((start_end_times.start_time - start_end_times.start_time.shift(1)).dropna() / np.timedelta64(1, "m")).round(0)
    return result


def make_game_time_features(assessment, history, title):
    result = {
        "games_played": history.game_session.nunique(),
    }
    return result

    
def apply_on_sessions(assessment, history, n_lags, func_list, title):
    result = {}
    empty = history.head(0)
    if n_lags:
        last_sessions = history.game_session.unique()[-n_lags:]
        for i in range(n_lags):
            for get_features in func_list:
                if i < len(last_sessions):
                    lag_features = get_features(assessment, history[history.game_session==last_sessions[i]], title)
                else:
                    lag_features = get_features(assessment, empty, title)
                features = {}
                for k, v in lag_features.items():
                    features["%s %d" % (k, i)] = v
                result.update(features)
    return result


def make_calendar_features(assessment, history):
    ts = assessment.timestamp
    year = ts.year
    month = ts.month
    dayofweek = ts.dayofweek
    time = ts.time()
    return {
        "dayofweek": dayofweek,
        "hour": time.hour,
    }


def make_base_features(assessment, history):
    return  {
        "title": games.index(assessment.title)
    }

base_stats = [populate_correct_moves]
base_features = [make_base_features, make_calendar_features, make_base_time_features]
game_features = [make_move_stats, make_game_time_features]
lag_features = [make_move_stats]
round_features = [make_move_stats]

def get_base_features(assessment, history):
    result = {}
    for f in base_features:
        result.update(f(assessment, history))
    return result


def get_game_features(assessment, stats, game):
    result = {}
    for f in game_features:
        result.update({game + " " + k: v for k, v in f(assessment, stats, game).items()})
    return result


def get_lag_features(assessment, stats, game, n_lags):
    res = {}
    result = apply_on_sessions(assessment, stats, n_lags, lag_features, game)
    for k, v in result.items():
        res[game + " " + k] = v
    return res       


def get_round_features(assessment, stats, game):
    result = {}
    rounds = stats.groupby("round")
    for round_name, group in rounds:
        for f in round_features:
            result.update({f"{k} game={game} round={round_name} ": v for k, v in f(assessment, group, game).items()})
    return result


def process_log(df):
    assessment = df.iloc[-1]
    history = df.iloc[:-1]
    history = history[history.type.isin(["Game", "Assessment"])]
    
    if len(history):
        history = unwrap_event_data(history)
    else:
        return {}
    history.sort_values("timestamp", inplace=True)
    
    for f in base_stats:
        history = f(history)
    
    history = json_normalize(history.groupby("game_session").apply(shrink_session))
    history.sort_values("start_time", inplace=True)
    result = {}
    result.update(get_base_features(assessment, history))
    for game in games:
        stats=history[history.title==game]
        result.update(get_game_features(assessment, stats, game))
        result.update(get_lag_features(assessment, stats, game, 2))
        if "round" in stats.columns:
            
    return result

# %%
train_features = process_installations_parallel(process_installations, process_log, train_labels, train)

# %%
if "index" in train_features.columns:
    raise RuntimeError()

# %%
train_features.to_csv(DATA_DIR / "interim/train_features_time_features.csv")

# %%
with open("../dsb2019/models/game_baseline_params.json", "r") as f:
    game_params=json.load(f)

def lgb_quad_kappa(preds, true):
    true = true.get_label()
    preds = preds.reshape((4, -1)).argmax(axis=0)
    return "quad_kappa", quad_kappa(true, preds), True
    
    
def train_baseline(x_train,y_train, params=None):
    x_train_all, x_val_all,y_train_all,y_val_all = train_test_split(
        x_train,y_train,
        test_size=0.15,
        random_state=2019,
    )
    train_set = lgb.Dataset(x_train_all, y_train_all)
    val_set = lgb.Dataset(x_val_all, y_val_all)
    return lgb.train(params, train_set, num_boost_round=10000, early_stopping_rounds=2000, valid_sets=[train_set, val_set], verbose_eval=100,
                    feval=lgb_quad_kappa)


def make_features_wrapper(train, test):
    def make_features(df):
        return df.drop(["installation_id", "accuracy_group"], axis=1), df.accuracy_group.values
    
    return make_features(train), make_features(test) 


def make_predictions(model,x_test_all,y_test):
    pred=model.predict(x_test_all).argmax(axis=1)
    return pred,y_test

# %%
train_baseline_params=partial(train_baseline,params=game_params)
predictions = cross_validate(train_features, train_features.accuracy_group, make_features_wrapper, train_baseline_params, make_predictions)
# Out:
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 2000 rounds
# [100]	training's multi_logloss: 1.09229	training's quad_kappa: 0.193104	valid_1's multi_logloss: 1.14917	valid_1's quad_kappa: 0.175646
# [200]	training's multi_logloss: 1.01216	training's quad_kappa: 0.455766	valid_1's multi_logloss: 1.09576	valid_1's quad_kappa: 0.402612
# [300]	training's multi_logloss: 0.960127	training's quad_kappa: 0.518416	valid_1's multi_logloss: 1.06829	valid_1's quad_kappa: 0.452257
# [400]	training's multi_logloss: 0.920914	training's quad_kappa: 0.546104	valid_1's multi_logloss: 1.05233	valid_1's quad_kappa: 0.473539
# [500]	training's multi_logloss: 0.890457	training's quad_kappa: 0.566831	valid_1's multi_logloss: 1.04366	valid_1's quad_kappa: 0.486777
# [600]	training's multi_logloss: 0.864355	training's quad_kappa: 0.582828	valid_1's multi_logloss: 1.03797	valid_1's quad_kappa: 0.486868
# [700]	training's multi_logloss: 0.841487	training's quad_kappa: 0.592549	valid_1's multi_logloss: 1.03433	valid_1's quad_kappa: 0.492604
# [800]	training's multi_logloss: 0.821309	training's quad_kappa: 0.604674	valid_1's multi_logloss: 1.03199	valid_1's quad_kappa: 0.488121
# [900]	training's multi_logloss: 0.803161	training's quad_kappa: 0.613951	valid_1's multi_logloss: 1.03026	valid_1's quad_kappa: 0.490561
# [1000]	training's multi_logloss: 0.786453	training's quad_kappa: 0.623474	valid_1's multi_logloss: 1.02906	valid_1's quad_kappa: 0.489939
# [1100]	training's multi_logloss: 0.770886	training's quad_kappa: 0.632099	valid_1's multi_logloss: 1.02855	valid_1's quad_kappa: 0.491933
# [1200]	training's multi_logloss: 0.756685	training's quad_kappa: 0.64213	valid_1's multi_logloss: 1.02831	valid_1's quad_kappa: 0.490551
# [1300]	training's multi_logloss: 0.743288	training's quad_kappa: 0.651566	valid_1's multi_logloss: 1.02829	valid_1's quad_kappa: 0.48792
# [1400]	training's multi_logloss: 0.73027	training's quad_kappa: 0.660611	valid_1's multi_logloss: 1.02843	valid_1's quad_kappa: 0.490441
# [1500]	training's multi_logloss: 0.717938	training's quad_kappa: 0.668761	valid_1's multi_logloss: 1.02876	valid_1's quad_kappa: 0.492617
# [1600]	training's multi_logloss: 0.706056	training's quad_kappa: 0.675413	valid_1's multi_logloss: 1.02919	valid_1's quad_kappa: 0.497225
# [1700]	training's multi_logloss: 0.694804	training's quad_kappa: 0.68159	valid_1's multi_logloss: 1.02967	valid_1's quad_kappa: 0.495635
# [1800]	training's multi_logloss: 0.683719	training's quad_kappa: 0.689725	valid_1's multi_logloss: 1.0303	valid_1's quad_kappa: 0.495012
# [1900]	training's multi_logloss: 0.673187	training's quad_kappa: 0.694723	valid_1's multi_logloss: 1.03089	valid_1's quad_kappa: 0.500204
# [2000]	training's multi_logloss: 0.662956	training's quad_kappa: 0.699923	valid_1's multi_logloss: 1.03193	valid_1's quad_kappa: 0.495754
# [2100]	training's multi_logloss: 0.65296	training's quad_kappa: 0.704772	valid_1's multi_logloss: 1.03313	valid_1's quad_kappa: 0.4971
# [2200]	training's multi_logloss: 0.643171	training's quad_kappa: 0.711211	valid_1's multi_logloss: 1.034	valid_1's quad_kappa: 0.498891
# [2300]	training's multi_logloss: 0.633751	training's quad_kappa: 0.717945	valid_1's multi_logloss: 1.03529	valid_1's quad_kappa: 0.498032
# [2400]	training's multi_logloss: 0.624597	training's quad_kappa: 0.723389	valid_1's multi_logloss: 1.03644	valid_1's quad_kappa: 0.497161
# [2500]	training's multi_logloss: 0.615488	training's quad_kappa: 0.729074	valid_1's multi_logloss: 1.03776	valid_1's quad_kappa: 0.498861
# [2600]	training's multi_logloss: 0.606919	training's quad_kappa: 0.733113	valid_1's multi_logloss: 1.03917	valid_1's quad_kappa: 0.500147
# [2700]	training's multi_logloss: 0.598387	training's quad_kappa: 0.736535	valid_1's multi_logloss: 1.04075	valid_1's quad_kappa: 0.500473
# [2800]	training's multi_logloss: 0.589979	training's quad_kappa: 0.739538	valid_1's multi_logloss: 1.04233	valid_1's quad_kappa: 0.501292
# [2900]	training's multi_logloss: 0.581952	training's quad_kappa: 0.744396	valid_1's multi_logloss: 1.04395	valid_1's quad_kappa: 0.501735
# [3000]	training's multi_logloss: 0.574231	training's quad_kappa: 0.748682	valid_1's multi_logloss: 1.04545	valid_1's quad_kappa: 0.499925
# [3100]	training's multi_logloss: 0.5666	training's quad_kappa: 0.75345	valid_1's multi_logloss: 1.04733	valid_1's quad_kappa: 0.504418
# [3200]	training's multi_logloss: 0.559273	training's quad_kappa: 0.757339	valid_1's multi_logloss: 1.04936	valid_1's quad_kappa: 0.505347
# [3300]	training's multi_logloss: 0.552043	training's quad_kappa: 0.760285	valid_1's multi_logloss: 1.05101	valid_1's quad_kappa: 0.507665
# Early stopping, best iteration is:
# [1309]	training's multi_logloss: 0.742083	training's quad_kappa: 0.653082	valid_1's multi_logloss: 1.02821	valid_1's quad_kappa: 0.488718
# Training until validation scores don't improve for 2000 rounds
# [100]	training's multi_logloss: 1.09779	training's quad_kappa: 0.203923	valid_1's multi_logloss: 1.13239	valid_1's quad_kappa: 0.165029
# [200]	training's multi_logloss: 1.01708	training's quad_kappa: 0.460122	valid_1's multi_logloss: 1.07664	valid_1's quad_kappa: 0.407629
# [300]	training's multi_logloss: 0.965127	training's quad_kappa: 0.51857	valid_1's multi_logloss: 1.0467	valid_1's quad_kappa: 0.461506
# [400]	training's multi_logloss: 0.926167	training's quad_kappa: 0.541964	valid_1's multi_logloss: 1.02813	valid_1's quad_kappa: 0.487635
# [500]	training's multi_logloss: 0.895831	training's quad_kappa: 0.562654	valid_1's multi_logloss: 1.0176	valid_1's quad_kappa: 0.504031
# [600]	training's multi_logloss: 0.870569	training's quad_kappa: 0.581948	valid_1's multi_logloss: 1.01068	valid_1's quad_kappa: 0.509264
# [700]	training's multi_logloss: 0.848381	training's quad_kappa: 0.593996	valid_1's multi_logloss: 1.00577	valid_1's quad_kappa: 0.509992
# [800]	training's multi_logloss: 0.828614	training's quad_kappa: 0.604896	valid_1's multi_logloss: 1.00233	valid_1's quad_kappa: 0.513628
# [900]	training's multi_logloss: 0.810625	training's quad_kappa: 0.613172	valid_1's multi_logloss: 1.00017	valid_1's quad_kappa: 0.515534
# [1000]	training's multi_logloss: 0.794151	training's quad_kappa: 0.622077	valid_1's multi_logloss: 0.998829	valid_1's quad_kappa: 0.514961
# [1100]	training's multi_logloss: 0.778911	training's quad_kappa: 0.63168	valid_1's multi_logloss: 0.997965	valid_1's quad_kappa: 0.516324
# [1200]	training's multi_logloss: 0.764585	training's quad_kappa: 0.640706	valid_1's multi_logloss: 0.997319	valid_1's quad_kappa: 0.517941
# [1300]	training's multi_logloss: 0.7511	training's quad_kappa: 0.648101	valid_1's multi_logloss: 0.996904	valid_1's quad_kappa: 0.523982
# [1400]	training's multi_logloss: 0.738154	training's quad_kappa: 0.658113	valid_1's multi_logloss: 0.997166	valid_1's quad_kappa: 0.519997
# [1500]	training's multi_logloss: 0.725813	training's quad_kappa: 0.665473	valid_1's multi_logloss: 0.997514	valid_1's quad_kappa: 0.521983
# [1600]	training's multi_logloss: 0.713805	training's quad_kappa: 0.673218	valid_1's multi_logloss: 0.997968	valid_1's quad_kappa: 0.52576
# [1700]	training's multi_logloss: 0.702536	training's quad_kappa: 0.678167	valid_1's multi_logloss: 0.998629	valid_1's quad_kappa: 0.52337
# [1800]	training's multi_logloss: 0.691665	training's quad_kappa: 0.683384	valid_1's multi_logloss: 0.999163	valid_1's quad_kappa: 0.522996
# [1900]	training's multi_logloss: 0.681216	training's quad_kappa: 0.689908	valid_1's multi_logloss: 1.00012	valid_1's quad_kappa: 0.521385
# [2000]	training's multi_logloss: 0.671143	training's quad_kappa: 0.696636	valid_1's multi_logloss: 1.00118	valid_1's quad_kappa: 0.519663
# [2100]	training's multi_logloss: 0.661343	training's quad_kappa: 0.703129	valid_1's multi_logloss: 1.00249	valid_1's quad_kappa: 0.520271
# [2200]	training's multi_logloss: 0.651964	training's quad_kappa: 0.708498	valid_1's multi_logloss: 1.00362	valid_1's quad_kappa: 0.521887
# [2300]	training's multi_logloss: 0.642799	training's quad_kappa: 0.712667	valid_1's multi_logloss: 1.00458	valid_1's quad_kappa: 0.521745
# [2400]	training's multi_logloss: 0.63361	training's quad_kappa: 0.719921	valid_1's multi_logloss: 1.00558	valid_1's quad_kappa: 0.521465
# [2500]	training's multi_logloss: 0.62477	training's quad_kappa: 0.725848	valid_1's multi_logloss: 1.00671	valid_1's quad_kappa: 0.519694
# [2600]	training's multi_logloss: 0.615985	training's quad_kappa: 0.731352	valid_1's multi_logloss: 1.00741	valid_1's quad_kappa: 0.519359
# [2700]	training's multi_logloss: 0.607344	training's quad_kappa: 0.737055	valid_1's multi_logloss: 1.0087	valid_1's quad_kappa: 0.516266
# [2800]	training's multi_logloss: 0.598976	training's quad_kappa: 0.742027	valid_1's multi_logloss: 1.00978	valid_1's quad_kappa: 0.515948
# [2900]	training's multi_logloss: 0.590812	training's quad_kappa: 0.747608	valid_1's multi_logloss: 1.0106	valid_1's quad_kappa: 0.516007
# [3000]	training's multi_logloss: 0.583015	training's quad_kappa: 0.753364	valid_1's multi_logloss: 1.01155	valid_1's quad_kappa: 0.514795
# [3100]	training's multi_logloss: 0.575233	training's quad_kappa: 0.758344	valid_1's multi_logloss: 1.01261	valid_1's quad_kappa: 0.516731
# [3200]	training's multi_logloss: 0.567617	training's quad_kappa: 0.762041	valid_1's multi_logloss: 1.01388	valid_1's quad_kappa: 0.516771
# [3300]	training's multi_logloss: 0.560275	training's quad_kappa: 0.764994	valid_1's multi_logloss: 1.01509	valid_1's quad_kappa: 0.51692
# Early stopping, best iteration is:
# [1300]	training's multi_logloss: 0.7511	training's quad_kappa: 0.648101	valid_1's multi_logloss: 0.996904	valid_1's quad_kappa: 0.523982
# Training until validation scores don't improve for 2000 rounds
# [100]	training's multi_logloss: 1.09445	training's quad_kappa: 0.200554	valid_1's multi_logloss: 1.13743	valid_1's quad_kappa: 0.195713
# [200]	training's multi_logloss: 1.0142	training's quad_kappa: 0.472667	valid_1's multi_logloss: 1.07905	valid_1's quad_kappa: 0.443473
# [300]	training's multi_logloss: 0.962539	training's quad_kappa: 0.526473	valid_1's multi_logloss: 1.04794	valid_1's quad_kappa: 0.485397
# [400]	training's multi_logloss: 0.923411	training's quad_kappa: 0.549763	valid_1's multi_logloss: 1.02826	valid_1's quad_kappa: 0.496503
# [500]	training's multi_logloss: 0.893293	training's quad_kappa: 0.564942	valid_1's multi_logloss: 1.01706	valid_1's quad_kappa: 0.508824
# [600]	training's multi_logloss: 0.867666	training's quad_kappa: 0.577301	valid_1's multi_logloss: 1.00914	valid_1's quad_kappa: 0.515929
# [700]	training's multi_logloss: 0.845331	training's quad_kappa: 0.587879	valid_1's multi_logloss: 1.00418	valid_1's quad_kappa: 0.514189
# [800]	training's multi_logloss: 0.825577	training's quad_kappa: 0.59903	valid_1's multi_logloss: 1.00098	valid_1's quad_kappa: 0.519389
# [900]	training's multi_logloss: 0.808058	training's quad_kappa: 0.607248	valid_1's multi_logloss: 0.999303	valid_1's quad_kappa: 0.521203
# [1000]	training's multi_logloss: 0.791626	training's quad_kappa: 0.61813	valid_1's multi_logloss: 0.997991	valid_1's quad_kappa: 0.524125
# [1100]	training's multi_logloss: 0.776487	training's quad_kappa: 0.62983	valid_1's multi_logloss: 0.997275	valid_1's quad_kappa: 0.524001
# [1200]	training's multi_logloss: 0.762368	training's quad_kappa: 0.639098	valid_1's multi_logloss: 0.9972	valid_1's quad_kappa: 0.526249
# [1300]	training's multi_logloss: 0.748858	training's quad_kappa: 0.644468	valid_1's multi_logloss: 0.997184	valid_1's quad_kappa: 0.530653
# [1400]	training's multi_logloss: 0.73596	training's quad_kappa: 0.651474	valid_1's multi_logloss: 0.997512	valid_1's quad_kappa: 0.530827
# [1500]	training's multi_logloss: 0.72371	training's quad_kappa: 0.65926	valid_1's multi_logloss: 0.998216	valid_1's quad_kappa: 0.535037
# [1600]	training's multi_logloss: 0.711826	training's quad_kappa: 0.66836	valid_1's multi_logloss: 0.999314	valid_1's quad_kappa: 0.535767
# [1700]	training's multi_logloss: 0.700297	training's quad_kappa: 0.674657	valid_1's multi_logloss: 1.00006	valid_1's quad_kappa: 0.537518
# [1800]	training's multi_logloss: 0.689344	training's quad_kappa: 0.681497	valid_1's multi_logloss: 1.00091	valid_1's quad_kappa: 0.536245
# [1900]	training's multi_logloss: 0.678898	training's quad_kappa: 0.687311	valid_1's multi_logloss: 1.00203	valid_1's quad_kappa: 0.534678
# [2000]	training's multi_logloss: 0.668591	training's quad_kappa: 0.692973	valid_1's multi_logloss: 1.00318	valid_1's quad_kappa: 0.532716
# [2100]	training's multi_logloss: 0.658674	training's quad_kappa: 0.699488	valid_1's multi_logloss: 1.0048	valid_1's quad_kappa: 0.532552
# [2200]	training's multi_logloss: 0.648998	training's quad_kappa: 0.704951	valid_1's multi_logloss: 1.00622	valid_1's quad_kappa: 0.529469
# [2300]	training's multi_logloss: 0.639717	training's quad_kappa: 0.710915	valid_1's multi_logloss: 1.00729	valid_1's quad_kappa: 0.528895
# [2400]	training's multi_logloss: 0.630462	training's quad_kappa: 0.715929	valid_1's multi_logloss: 1.00856	valid_1's quad_kappa: 0.525883
# [2500]	training's multi_logloss: 0.62188	training's quad_kappa: 0.721248	valid_1's multi_logloss: 1.00981	valid_1's quad_kappa: 0.528507
# [2600]	training's multi_logloss: 0.613421	training's quad_kappa: 0.726402	valid_1's multi_logloss: 1.01118	valid_1's quad_kappa: 0.534697
# [2700]	training's multi_logloss: 0.605137	training's quad_kappa: 0.731519	valid_1's multi_logloss: 1.01241	valid_1's quad_kappa: 0.532458
# [2800]	training's multi_logloss: 0.597326	training's quad_kappa: 0.735552	valid_1's multi_logloss: 1.01372	valid_1's quad_kappa: 0.532065
# [2900]	training's multi_logloss: 0.589583	training's quad_kappa: 0.73942	valid_1's multi_logloss: 1.01477	valid_1's quad_kappa: 0.53193
# [3000]	training's multi_logloss: 0.581956	training's quad_kappa: 0.743959	valid_1's multi_logloss: 1.01611	valid_1's quad_kappa: 0.53529
# [3100]	training's multi_logloss: 0.574675	training's quad_kappa: 0.747359	valid_1's multi_logloss: 1.01774	valid_1's quad_kappa: 0.532392
# [3200]	training's multi_logloss: 0.567278	training's quad_kappa: 0.750066	valid_1's multi_logloss: 1.01888	valid_1's quad_kappa: 0.532389
# Early stopping, best iteration is:
# [1223]	training's multi_logloss: 0.759184	training's quad_kappa: 0.640564	valid_1's multi_logloss: 0.997104	valid_1's quad_kappa: 0.529006
# Training until validation scores don't improve for 2000 rounds
# [100]	training's multi_logloss: 1.09058	training's quad_kappa: 0.199938	valid_1's multi_logloss: 1.11139	valid_1's quad_kappa: 0.175538
# [200]	training's multi_logloss: 1.00995	training's quad_kappa: 0.468183	valid_1's multi_logloss: 1.05445	valid_1's quad_kappa: 0.461368
# [300]	training's multi_logloss: 0.958034	training's quad_kappa: 0.527971	valid_1's multi_logloss: 1.02381	valid_1's quad_kappa: 0.495767
# [400]	training's multi_logloss: 0.918714	training's quad_kappa: 0.554513	valid_1's multi_logloss: 1.00454	valid_1's quad_kappa: 0.506805
# [500]	training's multi_logloss: 0.888194	training's quad_kappa: 0.568618	valid_1's multi_logloss: 0.993055	valid_1's quad_kappa: 0.521103
# [600]	training's multi_logloss: 0.862416	training's quad_kappa: 0.582261	valid_1's multi_logloss: 0.985298	valid_1's quad_kappa: 0.52716
# [700]	training's multi_logloss: 0.839532	training's quad_kappa: 0.591568	valid_1's multi_logloss: 0.97994	valid_1's quad_kappa: 0.530662
# [800]	training's multi_logloss: 0.819373	training's quad_kappa: 0.602288	valid_1's multi_logloss: 0.976874	valid_1's quad_kappa: 0.532455
# [900]	training's multi_logloss: 0.801288	training's quad_kappa: 0.613903	valid_1's multi_logloss: 0.975138	valid_1's quad_kappa: 0.532222
# [1000]	training's multi_logloss: 0.78472	training's quad_kappa: 0.624631	valid_1's multi_logloss: 0.973793	valid_1's quad_kappa: 0.536138
# [1100]	training's multi_logloss: 0.769515	training's quad_kappa: 0.632906	valid_1's multi_logloss: 0.973381	valid_1's quad_kappa: 0.535692
# [1200]	training's multi_logloss: 0.755097	training's quad_kappa: 0.638677	valid_1's multi_logloss: 0.972977	valid_1's quad_kappa: 0.53661
# [1300]	training's multi_logloss: 0.741366	training's quad_kappa: 0.648558	valid_1's multi_logloss: 0.972668	valid_1's quad_kappa: 0.537686
# [1400]	training's multi_logloss: 0.728243	training's quad_kappa: 0.657218	valid_1's multi_logloss: 0.972443	valid_1's quad_kappa: 0.538276
# [1500]	training's multi_logloss: 0.715678	training's quad_kappa: 0.663184	valid_1's multi_logloss: 0.972686	valid_1's quad_kappa: 0.542955
# [1600]	training's multi_logloss: 0.703695	training's quad_kappa: 0.670757	valid_1's multi_logloss: 0.973072	valid_1's quad_kappa: 0.545809
# [1700]	training's multi_logloss: 0.692216	training's quad_kappa: 0.678482	valid_1's multi_logloss: 0.973473	valid_1's quad_kappa: 0.546864
# [1800]	training's multi_logloss: 0.680886	training's quad_kappa: 0.686134	valid_1's multi_logloss: 0.973902	valid_1's quad_kappa: 0.545206
# [1900]	training's multi_logloss: 0.670246	training's quad_kappa: 0.691938	valid_1's multi_logloss: 0.974636	valid_1's quad_kappa: 0.547381
# [2000]	training's multi_logloss: 0.660124	training's quad_kappa: 0.696746	valid_1's multi_logloss: 0.975588	valid_1's quad_kappa: 0.551006
# [2100]	training's multi_logloss: 0.649977	training's quad_kappa: 0.702136	valid_1's multi_logloss: 0.976274	valid_1's quad_kappa: 0.55176
# [2200]	training's multi_logloss: 0.640209	training's quad_kappa: 0.708215	valid_1's multi_logloss: 0.977216	valid_1's quad_kappa: 0.551866
# [2300]	training's multi_logloss: 0.630878	training's quad_kappa: 0.713969	valid_1's multi_logloss: 0.978149	valid_1's quad_kappa: 0.553261
# [2400]	training's multi_logloss: 0.621709	training's quad_kappa: 0.7188	valid_1's multi_logloss: 0.9791	valid_1's quad_kappa: 0.550794
# [2500]	training's multi_logloss: 0.612657	training's quad_kappa: 0.726855	valid_1's multi_logloss: 0.980285	valid_1's quad_kappa: 0.55287
# [2600]	training's multi_logloss: 0.603943	training's quad_kappa: 0.734023	valid_1's multi_logloss: 0.981344	valid_1's quad_kappa: 0.551842
# [2700]	training's multi_logloss: 0.595408	training's quad_kappa: 0.740175	valid_1's multi_logloss: 0.982307	valid_1's quad_kappa: 0.553385
# [2800]	training's multi_logloss: 0.587142	training's quad_kappa: 0.744186	valid_1's multi_logloss: 0.983594	valid_1's quad_kappa: 0.553142
# [2900]	training's multi_logloss: 0.579067	training's quad_kappa: 0.748543	valid_1's multi_logloss: 0.984947	valid_1's quad_kappa: 0.551224
# [3000]	training's multi_logloss: 0.571214	training's quad_kappa: 0.754045	valid_1's multi_logloss: 0.986548	valid_1's quad_kappa: 0.55136
# [3100]	training's multi_logloss: 0.563566	training's quad_kappa: 0.75736	valid_1's multi_logloss: 0.987892	valid_1's quad_kappa: 0.552247
# [3200]	training's multi_logloss: 0.556006	training's quad_kappa: 0.761203	valid_1's multi_logloss: 0.98933	valid_1's quad_kappa: 0.551556
# [3300]	training's multi_logloss: 0.54871	training's quad_kappa: 0.765856	valid_1's multi_logloss: 0.990544	valid_1's quad_kappa: 0.5488
# [3400]	training's multi_logloss: 0.541385	training's quad_kappa: 0.770534	valid_1's multi_logloss: 0.991717	valid_1's quad_kappa: 0.547432
# Early stopping, best iteration is:
# [1436]	training's multi_logloss: 0.72363	training's quad_kappa: 0.659946	valid_1's multi_logloss: 0.972394	valid_1's quad_kappa: 0.541804
# Training until validation scores don't improve for 2000 rounds
# [100]	training's multi_logloss: 1.08891	training's quad_kappa: 0.205514	valid_1's multi_logloss: 1.13924	valid_1's quad_kappa: 0.17313
# [200]	training's multi_logloss: 1.0072	training's quad_kappa: 0.46867	valid_1's multi_logloss: 1.08212	valid_1's quad_kappa: 0.431054
# [300]	training's multi_logloss: 0.954388	training's quad_kappa: 0.528377	valid_1's multi_logloss: 1.05175	valid_1's quad_kappa: 0.467981
# [400]	training's multi_logloss: 0.914456	training's quad_kappa: 0.555349	valid_1's multi_logloss: 1.03272	valid_1's quad_kappa: 0.490113
# [500]	training's multi_logloss: 0.883555	training's quad_kappa: 0.574163	valid_1's multi_logloss: 1.02212	valid_1's quad_kappa: 0.509091
# [600]	training's multi_logloss: 0.857139	training's quad_kappa: 0.589992	valid_1's multi_logloss: 1.01525	valid_1's quad_kappa: 0.512793
# [700]	training's multi_logloss: 0.834244	training's quad_kappa: 0.602222	valid_1's multi_logloss: 1.0108	valid_1's quad_kappa: 0.511319
# [800]	training's multi_logloss: 0.813504	training's quad_kappa: 0.610148	valid_1's multi_logloss: 1.00766	valid_1's quad_kappa: 0.514891
# [900]	training's multi_logloss: 0.79484	training's quad_kappa: 0.62157	valid_1's multi_logloss: 1.00605	valid_1's quad_kappa: 0.515189
# [1000]	training's multi_logloss: 0.777764	training's quad_kappa: 0.632138	valid_1's multi_logloss: 1.00487	valid_1's quad_kappa: 0.513197
# [1100]	training's multi_logloss: 0.762083	training's quad_kappa: 0.639032	valid_1's multi_logloss: 1.00447	valid_1's quad_kappa: 0.515719
# [1200]	training's multi_logloss: 0.7476	training's quad_kappa: 0.647882	valid_1's multi_logloss: 1.00462	valid_1's quad_kappa: 0.51854
# [1300]	training's multi_logloss: 0.733754	training's quad_kappa: 0.654552	valid_1's multi_logloss: 1.00483	valid_1's quad_kappa: 0.521639
# [1400]	training's multi_logloss: 0.720644	training's quad_kappa: 0.662068	valid_1's multi_logloss: 1.00545	valid_1's quad_kappa: 0.520547
# [1500]	training's multi_logloss: 0.707846	training's quad_kappa: 0.670742	valid_1's multi_logloss: 1.00606	valid_1's quad_kappa: 0.520333
# [1600]	training's multi_logloss: 0.695866	training's quad_kappa: 0.679294	valid_1's multi_logloss: 1.00677	valid_1's quad_kappa: 0.523258
# [1700]	training's multi_logloss: 0.684139	training's quad_kappa: 0.68522	valid_1's multi_logloss: 1.0075	valid_1's quad_kappa: 0.520735
# [1800]	training's multi_logloss: 0.672862	training's quad_kappa: 0.692396	valid_1's multi_logloss: 1.00846	valid_1's quad_kappa: 0.522555
# [1900]	training's multi_logloss: 0.661809	training's quad_kappa: 0.698315	valid_1's multi_logloss: 1.00909	valid_1's quad_kappa: 0.524554
# [2000]	training's multi_logloss: 0.651064	training's quad_kappa: 0.704997	valid_1's multi_logloss: 1.0099	valid_1's quad_kappa: 0.524015
# [2100]	training's multi_logloss: 0.640903	training's quad_kappa: 0.711087	valid_1's multi_logloss: 1.01126	valid_1's quad_kappa: 0.521498
# [2200]	training's multi_logloss: 0.631134	training's quad_kappa: 0.717045	valid_1's multi_logloss: 1.01247	valid_1's quad_kappa: 0.515298
# [2300]	training's multi_logloss: 0.621729	training's quad_kappa: 0.724095	valid_1's multi_logloss: 1.01381	valid_1's quad_kappa: 0.518478
# [2400]	training's multi_logloss: 0.612431	training's quad_kappa: 0.730485	valid_1's multi_logloss: 1.01514	valid_1's quad_kappa: 0.513941
# [2500]	training's multi_logloss: 0.603198	training's quad_kappa: 0.734187	valid_1's multi_logloss: 1.01645	valid_1's quad_kappa: 0.514674
# [2600]	training's multi_logloss: 0.594488	training's quad_kappa: 0.740058	valid_1's multi_logloss: 1.01796	valid_1's quad_kappa: 0.516869
# [2700]	training's multi_logloss: 0.586129	training's quad_kappa: 0.744834	valid_1's multi_logloss: 1.01928	valid_1's quad_kappa: 0.517127
# [2800]	training's multi_logloss: 0.577797	training's quad_kappa: 0.750262	valid_1's multi_logloss: 1.02087	valid_1's quad_kappa: 0.514872
# [2900]	training's multi_logloss: 0.56989	training's quad_kappa: 0.755213	valid_1's multi_logloss: 1.02242	valid_1's quad_kappa: 0.516956
# [3000]	training's multi_logloss: 0.562012	training's quad_kappa: 0.759827	valid_1's multi_logloss: 1.02397	valid_1's quad_kappa: 0.515794
# [3100]	training's multi_logloss: 0.554441	training's quad_kappa: 0.76367	valid_1's multi_logloss: 1.02563	valid_1's quad_kappa: 0.517478
# Early stopping, best iteration is:
# [1141]	training's multi_logloss: 0.756045	training's quad_kappa: 0.642791	valid_1's multi_logloss: 1.00441	valid_1's quad_kappa: 0.516053

# %%
mean_score, cv_scores = np.mean([quad_kappa(true, pred) for pred, true in predictions]), [quad_kappa(true, pred) for pred, true in predictions]

# %%
mean_score, cv_scores
# Out:
# (0.5121903799168784,
#  [0.5419158630512911,
#   0.5297429232943285,
#   0.5132261715178328,
#   0.49051709716613845,
#   0.48554984455480155])

# %%
(0.504415900635456,
 [0.5308435853458475,
  0.520947273474178,
  0.5038941378338113,
  0.48667353180548045,
  0.4797209747179626])
# Out:
# (0.504415900635456,
#  [0.5308435853458475,
#   0.520947273474178,
#   0.5038941378338113,
#   0.48667353180548045,
#   0.4797209747179626])

# %%
baseline_model=train_baseline(train_features.drop(["installation_id", "accuracy_group"], axis=1), train_features.accuracy_group.values, 
               params=game_params)

# %%
lgb.plot_importance(baseline_model, figsize=(10,20), max_num_features=100)

# %%
baseline_model.save_model(str(MODELS_DIR / "time_baseline.lgb"))

# %%
mean_score, cv_scores = (0.504415900635456,
 [0.5308435853458475,
  0.520947273474178,
  0.5038941378338113,
  0.48667353180548045,
  0.4797209747179626])
name = "Game baseline"
notebook_path="notebooks/Game baseline.ipynb"
submission_path="notebooks/submissions/Game baseline submission.ipynb"
track_experiment(name, mean_score, cv_scores, notebook_path)
track_submission_info(name, submission_path, 0.445)
# Out:
#                              name                              time  \
# 0                   Game baseline  2019-11-04 02:46:37.991522+04:00
# 1  Time + calendar features as is  2019-11-04 02:46:13.502097+04:00
#
#    mean_score  \
# 0    0.504416
# 1    0.509131
#
#                                                                                               cv_scores  \
# 0  [0.5308435853458475, 0.520947273474178, 0.5038941378338113, 0.48667353180548045, 0.4797209747179626]
# 1   [0.53695404946506, 0.5242692903114117, 0.5082992396170676, 0.4890864025859084, 0.48704737927505637]
#
#                    notebook_path  \
# 0  notebooks/Game baseline.ipynb
# 1            Time features.ipynb
#
#                                         submission_path  submission_score
# 0  notebooks/submissions/Game baseline submission.ipynb             0.445
# 1                                                   NaN               NaN

# %%
pd.options.display.max_colwidth = 999
track_experiment("Time + calendar features as is", 0.5091312722509007,
 [0.53695404946506,
  0.5242692903114117,
  0.5082992396170676,
  0.4890864025859084,
  0.48704737927505637], "Time features.ipynb")
# Out:
#                              name                              time  \
# 0                   Game baseline  2019-11-04 02:46:37.991522+04:00
# 1  Time + calendar features as is  2019-11-04 02:46:40.201648+04:00
#
#    mean_score  \
# 0    0.504416
# 1    0.509131
#
#                                                                                               cv_scores  \
# 0  [0.5308435853458475, 0.520947273474178, 0.5038941378338113, 0.48667353180548045, 0.4797209747179626]
# 1   [0.53695404946506, 0.5242692903114117, 0.5082992396170676, 0.4890864025859084, 0.48704737927505637]
#
#                    notebook_path  \
# 0  notebooks/Game baseline.ipynb
# 1            Time features.ipynb
#
#                                         submission_path  submission_score
# 0  notebooks/submissions/Game baseline submission.ipynb             0.445
# 1                                                   NaN               NaN
